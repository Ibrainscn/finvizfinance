# %% [markdown]
# # Finviz Finance

# %% [markdown]
# ## Quote

# %%
import pandas as pd
from finvizfinance.quote import finvizfinance

stock = finvizfinance('tsla')

# %%
stock

# %%
stock.ticker_charts()
# Out:
# 'https://finviz.com/chart.ashx?t=tsla&ty=c&ta=1&p=d'

# %%
from IPython.display import Image
Image(filename='tsla.jpg')

# %%
stock_fundament = stock.ticker_fundament()
stock_description = stock.ticker_description()
outer_ratings_df = stock.ticker_outer_ratings()
news_df = stock.ticker_news()
inside_trader_df = stock.ticker_inside_trader()

# %%
print(stock_fundament)
# Out:
# {'Company': 'Tesla, Inc.', 'Sector': 'Consumer Cyclical', 'Industry': 'Auto Manufacturers', 'Country': 'USA', 'Index': 'S&P 500', 'P/E': '333.21', 'EPS (ttm)': '3.08', 'Insider Own': '0.10%', 'Shs Outstand': '963.33M', 'Perf Week': '-2.82%', 'Market Cap': '989.30B', 'Forward P/E': '121.53', 'EPS next Y': '38.14%', 'Insider Trans': '-94.37%', 'Shs Float': '804.08M', 'Perf Month': '-3.93%', 'Income': '3.47B', 'PEG': '4.56', 'EPS next Q': '1.83', 'Inst Own': '42.50%', 'Short Float': '3.21%', 'Perf Quarter': '30.74%', 'Sales': '46.85B', 'P/S': '21.12', 'EPS this Y': '165.00%', 'Inst Trans': '4.63%', 'Short Ratio': '0.95', 'Perf Half Y': '49.77%', 'Book/sh': '27.11', 'P/B': '37.88', 'ROA': '6.40%', 'Target Price': '893.29', 'Perf Year': '16.70%', 'Cash/sh': '16.71', 'P/C': '61.47', 'EPS next 5Y': '73.06%', 'ROE': '14.30%', '52W Range From': '539.49', '52W Range To': '1243.49', 'Perf YTD': '-2.82%', 'Dividend': '-', 'P/FCF': '100.03', 'EPS past 5Y': '19.70%', 'ROI': '5.00%', '52W High': '-17.41%', 'Beta': '1.98', 'Dividend %': '-', 'Quick Ratio': '1.10', 'Sales past 5Y': '50.80%', 'Gross Margin': '23.10%', '52W Low': '90.36%', 'ATR': '64.40', 'Employees': '70757', 'Current Ratio': '1.40', 'Sales Q/Q': '56.80%', 'Oper. Margin': '9.60%', 'RSI (14)': '47.34', 'Volatility W': '7.04%', 'Volatility M': '5.48%', 'Optionable': 'Yes', 'Debt/Eq': '0.30', 'EPS Q/Q': '430.70%', 'Profit Margin': '7.40%', 'Rel Volume': '1.03', 'Prev Close': '1064.70', 'Shortable': 'Yes', 'LT Debt/Eq': '0.24', 'Earnings': 'Oct 20 AMC', 'Payout': '0.00%', 'Avg Volume': '27.08M', 'Price': '1026.96', 'Recom': '2.60', 'SMA20': '-0.26%', 'SMA50': '-4.35%', 'SMA200': '29.76%', 'Volume': '27,835,827', 'Change': '-3.54%'}

# %%
print(stock_description)
# Out:
# Tesla, Inc. designs, develops, manufactures, leases, and sells electric vehicles, and energy generation and storage systems in the United States, China, and internationally. The company operates in two segments, Automotive, and Energy Generation and Storage. The Automotive segment offers electric vehicles, as well as sells automotive regulatory credits. It provides sedans and sport utility vehicles through direct and used vehicle sales, a network of Tesla Superchargers, and in-app upgrades; and purchase financing and leasing services. This segment is also involved in the provision of non-warranty after-sales vehicle services, sale of used vehicles, retail merchandise, and vehicle insurance, as well as sale of products through its subsidiaries to third party customers; services for electric vehicles through its company-owned service locations, and Tesla mobile service technicians; and vehicle limited warranties and extended service plans. The Energy Generation and Storage segment engages in the design, manufacture, installation, sale, and leasing of solar energy generation and energy storage products, and related services to residential, commercial, and industrial customers and utilities through its website, stores, and galleries, as well as through a network of channel partners. This segment also offers service and repairs to its energy product customers, including under warranty; and various financing options to its solar customers. The company was formerly known as Tesla Motors, Inc. and changed its name to Tesla, Inc. in February 2017. Tesla, Inc. was founded in 2003 and is headquartered in Austin, Texas.

# %%
outer_ratings_df.head()
# Out:
#         Date      Status             Outer          Rating         Price
# 0 2022-01-05  Reiterated          Barclays     Underweight   $300 → $325
# 1 2022-01-03  Reiterated  RBC Capital Mkts  Sector Perform  $950 → $1005
# 2 2021-12-30  Reiterated         Citigroup            Sell   $236 → $262
# 3 2021-12-20   Initiated        Guggenheim         Neutral          $924
# 4 2021-12-07  Reiterated               UBS         Neutral  $725 → $1000

# %%
news_df.head()
# Out:
#                  Date                                              Title  \
# 0 2022-01-07 21:55:00  Dow Jones Futures: 2022 Market Is Expectation ...
# 1 2022-01-07 19:30:00  Mohamed El-Erian says trifecta of dangers will...
# 2 2022-01-07 19:23:00  Tesla Self Driving Is Getting So Good It Will ...
# 3 2022-01-07 18:55:00  Southwest, Apple, GameStop: Stocks That Define...
# 4 2022-01-07 18:11:00  Is Tesla Stock Headed to $1,400 or $67? Why Pr...
#
#                                                 Link
# 0  https://www.investors.com/market-trend/stock-m...
# 1  https://finance.yahoo.com/news/mohamed-el-eria...
# 2  https://www.barrons.com/articles/tesla-stock-s...
# 3  https://www.wsj.com/articles/southwest-apple-g...
# 4  https://www.barrons.com/articles/auto-stocks-h...

# %%
inside_trader_df.head()
# Out:
#     Insider Trading              Relationship    Date      Transaction  \
# 0    Taneja Vaibhav  Chief Accounting Officer  Jan 05  Option Exercise
# 1    Taneja Vaibhav  Chief Accounting Officer  Jan 05             Sale
# 2    Taneja Vaibhav  Chief Accounting Officer  Jan 05             Sale
# 3  Kirkhorn Zachary   Chief Financial Officer  Dec 31  Option Exercise
# 4         Musk Elon                       CEO  Dec 28  Option Exercise
#
#       Cost    #Shares  Value ($)  #Shares Total       SEC Form 4  \
# 0    54.66     7000.0   382620.0        29905.0  Jan 07 06:36 PM
# 1  1131.26     5900.0  6674424.0        24005.0  Jan 07 06:36 PM
# 2  1160.85     1100.0  1276940.0        22905.0  Jan 07 06:37 PM
# 3    55.32     3200.0   177024.0        58584.0  Jan 04 09:50 PM
# 4     6.24  1554176.0  9698058.0      1554176.0  Dec 28 08:47 PM
#
#                                      SEC Form 4 Link Insider_id
# 0  http://www.sec.gov/Archives/edgar/data/1318605...    1771340
# 1  http://www.sec.gov/Archives/edgar/data/1318605...    1771340
# 2  http://www.sec.gov/Archives/edgar/data/1318605...    1771340
# 3  http://www.sec.gov/Archives/edgar/data/1318605...    1771364
# 4  http://www.sec.gov/Archives/edgar/data/1318605...    1494730

# %%
stock.ticker_signal()
# Out:
# ['Most Active', 'Recent Insider Selling', 'Major News']

# %% [markdown]
# ## Statements

# %%
from finvizfinance.quote import Statements
statement = Statements()
df = statement.get_statements('AAPL', statement="B", timeframe="Q")
df.head()
# Out:
#                                           0          1          2           3  \
# Period End Date                   9/25/2021  6/26/2021  3/27/2021  12/26/2020
# Cash and Equivalents              17,635.00  19,197.00  19,022.00   17,281.00
# Short Term Investments            27,699.00  27,646.00  31,368.00   40,816.00
# Cash and Short Term Investments   62,639.00  61,696.00  69,834.00   76,826.00
# Accounts Receivable - Trade, Net  26,278.00  17,475.00  18,503.00   27,101.00
#
#                                           4          5          6           7
# Period End Date                   9/26/2020  6/27/2020  3/28/2020  12/28/2019
# Cash and Equivalents              20,243.00  13,130.00  15,769.00   28,388.00
# Short Term Investments            52,927.00  59,642.00  53,877.00   67,391.00
# Cash and Short Term Investments   90,943.00  93,025.00  94,051.00  107,162.00
# Accounts Receivable - Trade, Net  16,120.00  17,882.00  15,722.00   20,970.00

# %% [markdown]
# ## News

# %%
from finvizfinance.news import News
fnews = News()
all_news = fnews.get_news()

# %%
all_news['news'].head()
# Out:
#       Date                                              Title  \
# 0  12:01AM   Three women brutally killed in one day in France
# 1   Jan-07  The complicated politics around Novak Djokovic...
# 2   Jan-07  Russia's Border Tensions Translate Into Market...
# 3   Jan-07  Kudlow: Biden's $2 trillion boondoggle spendin...
# 4   Jan-07         Life sentences for killers of Black jogger
#
#                 Source                                               Link
# 0          www.cnn.com  https://www.cnn.com/2022/01/08/europe/france-s...
# 1          www.cnn.com  https://www.cnn.com/videos/world/2022/01/08/no...
# 2          www.wsj.com  https://www.wsj.com/articles/russias-border-te...
# 3  www.foxbusiness.com  https://www.foxbusiness.com/media/kudlow-biden...
# 4          www.cnn.com  https://www.cnn.com/2022/01/07/us/ahmaud-arber...

# %%
all_news['blogs'].head()
# Out:
#       Date                                              Title  \
# 0  12:00AM  Is There A Way To Prevent Psychopaths From Get...
# 1   Jan-07  Sports Illustrated Swimsuit Model Says Stalker...
# 2   Jan-07  What The Great Ammunition Shortage Says About ...
# 3   Jan-07  National Tire Shortage Emerges As Snowstorms P...
# 4   Jan-07  Buchanan: Russia Is Not The Great Rival; China Is
#
#               Source                                               Link
# 0  www.zerohedge.com  https://www.zerohedge.com/geopolitical/there-w...
# 1  www.zerohedge.com  https://www.zerohedge.com/technology/sports-il...
# 2  www.zerohedge.com  https://www.zerohedge.com/political/what-great...
# 3  www.zerohedge.com  https://www.zerohedge.com/markets/national-tir...
# 4  www.zerohedge.com  https://www.zerohedge.com/geopolitical/buchana...

# %% [markdown]
# ## Insider

# %%
from finvizfinance.insider import Insider
finsider = Insider(option='top owner trade')
finsider.get_insider().head()
# Out:
#   Ticker                           Owner Relationship    Date Transaction  \
# 0    WMG   AI Entertainment Holdings LLC    10% Owner  Jan 06        Sale
# 1    WMG   AI Entertainment Holdings LLC    10% Owner  Jan 06        Sale
# 2   TALO  Apollo Management Holdings GP,    10% Owner  Jan 03        Sale
# 3   TPGY  TYBOURNE CAPITAL MANAGEMENT (H    10% Owner  Dec 30        Sale
# 4    LPI  EnCap Energy Capital Fund IX,     10% Owner  Jan 06        Sale
#
#     Cost    #Shares    Value ($)  #Shares Total       SEC Form 4  \
# 0  40.66  4356680.0  177142609.0            0.0  Jan 07 05:04 PM
# 1  40.66  4205820.0  171008641.0            0.0  Jan 07 05:04 PM
# 2   9.35  6655136.0   62225522.0      2913180.0  Jan 04 04:31 PM
# 3   9.81  4817252.0   47238937.0            0.0  Jan 03 09:26 AM
# 4  73.00   500000.0   36500000.0      1691052.0  Jan 07 06:57 PM
#
#                                      SEC Form 4 Link
# 0  http://www.sec.gov/Archives/edgar/data/877116/...
# 1  http://www.sec.gov/Archives/edgar/data/877116/...
# 2  http://www.sec.gov/Archives/edgar/data/1398053...
# 3  http://www.sec.gov/Archives/edgar/data/1553936...
# 4  http://www.sec.gov/Archives/edgar/data/1528129...

# %% [markdown]
# Use case: getting specific insider information

# %%
from finvizfinance.insider import Insider
finsider = Insider(option='1771340')
finsider.get_insider().head()
# Out:
#   Ticker           Owner              Relationship    Date      Transaction  \
# 0   TSLA  Taneja Vaibhav  Chief Accounting Officer  Jan 05             Sale
# 1   TSLA  Taneja Vaibhav  Chief Accounting Officer  Jan 05  Option Exercise
# 2   TSLA  Taneja Vaibhav  Chief Accounting Officer  Jan 05             Sale
# 3   TSLA  Taneja Vaibhav  Chief Accounting Officer  Dec 05  Option Exercise
# 4   TSLA  Taneja Vaibhav  Chief Accounting Officer  Dec 06             Sale
#
#       Cost  #Shares  Value ($)  #Shares Total       SEC Form 4  \
# 0  1160.85   1100.0  1276940.0        22905.0  Jan 07 06:37 PM
# 1    54.66   7000.0   382620.0        29905.0  Jan 07 06:36 PM
# 2  1131.26   5900.0  6674424.0        24005.0  Jan 07 06:36 PM
# 3     0.00   3283.0        0.0        24495.0  Dec 07 09:11 PM
# 4   980.41   1590.0  1559339.0        22905.0  Dec 07 09:11 PM
#
#                                      SEC Form 4 Link
# 0  http://www.sec.gov/Archives/edgar/data/1318605...
# 1  http://www.sec.gov/Archives/edgar/data/1318605...
# 2  http://www.sec.gov/Archives/edgar/data/1318605...
# 3  http://www.sec.gov/Archives/edgar/data/1318605...
# 4  http://www.sec.gov/Archives/edgar/data/1318605...

# %% [markdown]
# ## Screener

# %% [markdown]
# Use case: setting filters

# %%
from finvizfinance.screener.overview import Overview
foverview = Overview()
filters_dict = {'Exchange':'AMEX','Sector':'Basic Materials'}
foverview.set_filter(filters_dict=filters_dict)
df = foverview.screener_view(order='Company')
df.head()
# Out:
# [Info] loading page [##############################] 3/3
#   Ticker                               Company           Sector  \
# 0    AXU                 Alexco Resource Corp.  Basic Materials
# 1    AAU                 Almaden Minerals Ltd.  Basic Materials
# 2   USAS  Americas Gold and Silver Corporation  Basic Materials
# 3    ASM        Avino Silver & Gold Mines Ltd.  Basic Materials
# 4    BTG                          B2Gold Corp.  Basic Materials
#
#                            Industry Country    Market Cap   P/E  Price  \
# 0    Other Precious Metals & Mining  Canada  3.174400e+08  None   1.64
# 1                              Gold  Canada  3.848000e+07  None   0.28
# 2  Other Industrial Metals & Mining  Canada  1.075000e+08  None   0.81
# 3                            Silver  Canada  9.717000e+07  None   0.79
# 4                              Gold  Canada  3.830000e+09  5.98   3.64
#
#    Change     Volume
# 0  0.0314   632361.0
# 1 -0.0191   644779.0
# 2  0.0212   289889.0
# 3  0.0167   273311.0
# 4 -0.0027  5954294.0

# %% [markdown]
# Use case: getting companys which are similar to TSLA.

# %%
ticker = 'tsla'
compare_list = ['Sector','Industry','Country']

from finvizfinance.screener.financial import Financial
ffinancial = Financial()
df = ffinancial.compare(ticker,compare_list,verbose=0)
df
# Out:
#    Ticker    Market Cap Dividend    ROA    ROE    ROI Curr R Quick R  \
# 0    AYRO  6.123000e+07     None -0.378   -0.4   None   14.2    13.7
# 1    BLBD  4.171400e+08     None -0.001  0.006  0.039    1.3     0.2
# 2    ELMS  7.928700e+08     None -0.181 -0.241   None    2.6     2.5
# 3       F  9.626000e+10   0.0164  0.011  0.084 -0.024    1.2     1.0
# 4    FFIE  1.690000e+09     None -0.044 -0.045   None    0.1     0.1
# 5     FSR  4.940000e+09     None -0.334 -0.421   None   18.4    18.4
# 6      GM  8.964000e+10     None  0.046   0.22  0.031    1.1     0.9
# 7    GOEV  1.750000e+09     None -0.424 -0.549  -0.34    4.0     4.0
# 8    HYZN  1.710000e+09     None  0.044  0.059   None   16.3    15.9
# 9    LCID  7.039000e+10     None  -1.48 -2.262   None   18.5    18.3
# 10   MULN  1.034500e+08     None -0.099 -0.616 -0.357    1.2     1.2
# 11   NKLA  4.460000e+09     None -0.669 -0.779   None   None    None
# 12   PTRA  2.010000e+09     None -0.374 -0.551   None   10.2     9.1
# 13   RIDE  6.562900e+08     None -0.547 -0.634   None    2.9     2.9
# 14   RIVN  7.748000e+10     None   None   None   None    5.1     5.0
# 15    SEV           NaN     None   None   None   None   None    None
# 16   TSLA  9.893000e+11     None  0.064  0.143   0.05    1.4     1.1
# 17   VLCN  1.080100e+08     None   None   None   None    1.6     1.1
# 18   WKHS  6.675900e+08     None  0.074  0.136 -0.114    1.9     1.5
#
#    LTDebt/Eq Debt/Eq Gross M Oper M Profit M  Earnings    Price  Change  \
# 0        0.0     0.0  -0.189   None     None  Nov 15/b     1.54  0.0032
# 1       None    None   0.105  0.009      0.0  Dec 15/a    15.60 -0.0064
# 2       0.11    0.31   0.015   None     None  Nov 10/a     6.42 -0.0346
# 3       2.66    3.95   0.101   0.01    0.021  Oct 27/a    24.44 -0.0008
# 4        0.0     0.0    None   None     None         -     5.36 -0.0480
# 5       0.73     0.0    None   None     None  Nov 03/a    16.24 -0.0055
# 6       1.37    2.01   0.143  0.081    0.084  Feb 01/a    62.27 -0.0095
# 7        0.0     0.0   0.737   None     None  Nov 15/a     7.00  0.0029
# 8        0.0     0.0  -0.006   None     None  Nov 12/b     6.68  0.0277
# 9        0.0    0.01    None   None     None  Nov 15/a    41.98  0.0984
# 10      1.29    1.37   0.127 -0.013   -0.029         -     4.70 -0.0581
# 11       0.0    0.04    None   None     None  Nov 04/b    10.62  0.0402
# 12      0.14    0.15   0.028   None     None  Nov 10/a     9.09  0.0044
# 13       0.0     0.0    None   None     None  Nov 11/a     3.29  0.0217
# 14      None    None    None   None     None  Dec 16/a    86.28 -0.0120
# 15      None    None    None   None     None         -     8.65  0.0273
# 16      0.24     0.3   0.231  0.096    0.074  Oct 20/a  1026.96 -0.0354
# 17      0.02    0.27    None   None     None         -     9.55 -0.0764
# 18      0.18    1.28    None   None     None  Nov 09/b     4.11  0.0024
#
#          Volume
# 0      594644.0
# 1       62189.0
# 2      138959.0
# 3   125922937.0
# 4      655200.0
# 5     5592160.0
# 6    16767340.0
# 7     2687097.0
# 8     2135559.0
# 9    78125078.0
# 10     588486.0
# 11   14038702.0
# 12    1611920.0
# 13    3895891.0
# 14   17484360.0
# 15     523079.0
# 16   27835827.0
# 17      33236.0
# 18    3918121.0

# %% [markdown]
# Use case: getting companys that have 'Triangle Ascending' signal.

# %%
signal = 'Triangle Ascending'
foverview.set_filter(signal=signal)
df = foverview.screener_view()
df.head()
# Out:
# [Info] loading page [##############################] 2/2
#   Ticker                                      Company              Sector  \
# 0    CGW           Invesco S&P Global Water Index ETF           Financial
# 1   ULTA                            Ulta Beauty, Inc.   Consumer Cyclical
# 2   OPCH                     Option Care Health, Inc.          Healthcare
# 3    PFF  iShares Preferred and Income Securities ETF           Financial
# 4  CHSCP                                     CHS Inc.  Consumer Defensive
#
#                   Industry Country    Market Cap    P/E   Price  Change  \
# 0     Exchange Traded Fund     USA           NaN    NaN   58.25 -0.0039
# 1         Specialty Retail     USA  2.119000e+10  25.41  397.10 -0.0085
# 2  Medical Care Facilities     USA  4.500000e+09  55.15   25.04 -0.0325
# 3     Exchange Traded Fund     USA           NaN    NaN   38.63 -0.0041
# 4            Farm Products     USA  3.779100e+08   None   30.90 -0.0006
#
#       Volume
# 0   149764.0
# 1   511251.0
# 2  1183949.0
# 3  8243891.0
# 4     8233.0

# %% [markdown]
# Use case: Getting individual company.

# %%
ticker='TSLA'
foverview.set_filter(signal='', filters_dict={}, ticker=ticker)
df = foverview.screener_view()
df.head()
# Out:
# [Info] loading page [##############################] 1/1
#   Ticker      Company             Sector            Industry Country  \
# 0   TSLA  Tesla, Inc.  Consumer Cyclical  Auto Manufacturers     USA
#
#      Market Cap     P/E    Price  Change      Volume
# 0  9.893000e+11  333.21  1026.96 -0.0354  27835827.0

# %% [markdown]
# # Forex

# %%
from finvizfinance.forex import Forex
fforex = Forex()
df = fforex.performance()
df
# Out:
#    Ticker       Price  Perf 5Min  Perf Hour  Perf Day  Perf Week  Perf Month  \
# 0  EURUSD      1.1361     0.0001    -0.0000    0.0058    -0.0020      0.0083
# 1  NZDUSD      0.6773    -0.0004    -0.0005    0.0041    -0.0107     -0.0020
# 2  GBPUSD      1.3585    -0.0005    -0.0008    0.0041     0.0039      0.0259
# 3  AUDUSD      0.7181     0.0000    -0.0001    0.0029    -0.0124      0.0087
# 4  GBPJPY      156.90    -0.0010    -0.0012    0.0015     0.0074      0.0438
# 5  EURGBP      0.8355    -0.0003    -0.0002    0.0012    -0.0067     -0.0174
# 6  BTCUSD  41890.3500    -0.0004    -0.0005   -0.0005    -0.1071     -0.1667
# 7  USDCHF      0.9183    -0.0001     0.0000   -0.0029     0.0073     -0.0071
# 8  USDJPY      115.47    -0.0007    -0.0007   -0.0030     0.0033      0.0171
# 9  USDCAD      1.2644    -0.0000     0.0002   -0.0063     0.0002      0.0005
#
#    Perf Quart  Perf Half  Perf Year  Perf YTD
# 0     -0.0164    -0.0364    -0.0741   -0.0020
# 1     -0.0217    -0.0346    -0.0663   -0.0107
# 2     -0.0021    -0.0155     0.0016    0.0039
# 3     -0.0173    -0.0401    -0.0755   -0.0124
# 4      0.0329     0.0283     0.1150    0.0074
# 5     -0.0148    -0.0216    -0.0759   -0.0067
# 6     -0.2219     0.2568     0.0814   -0.1031
# 7     -0.0101    -0.0077     0.0385    0.0073
# 8      0.0347     0.0441     0.1128    0.0033
# 9      0.0076     0.0134    -0.0036    0.0002

# %%
fforex.chart('audusd')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-7d89bc691568> in <module>
# ----> 1 fforex.chart('audusd')
#
# ~\anaconda3\lib\site-packages\finvizfinance\forex.py in chart(self, forex, timeframe, urlonly)
#      51
#      52         url = "https://finviz.com/forex_charts.ashx?t=ALL&tf="
# ---> 53         charturl = image_scrap_function(url, forex, timeframe, urlonly)
#      54         return charturl
#
# ~\anaconda3\lib\site-packages\finvizfinance\util.py in image_scrap_function(url, chart, timeframe, urlonly)
#     178     soup = web_scrap(url)
#     179     content = soup.find("div", class_="container")
# --> 180     imgs = content.findAll("img")
#     181     for img in imgs:
#     182         website = img["src"]
#
# AttributeError: 'NoneType' object has no attribute 'findAll'

# %% [markdown]
# # Crypto

# %%
from finvizfinance.crypto import Crypto
fcrypto = Crypto()
df = fcrypto.performance()
df
# Out:
#     Ticker       Price  Perf 5Min  Perf Hour  Perf Day  Perf Week  Perf Month  \
# 0   BTCEUR  36931.2500     0.0012     0.0012    0.0012    -0.1071     -0.1708
# 1   BTCUSD  41918.4000     0.0003     0.0001    0.0001    -0.1065     -0.1662
# 2   XRPBTC      0.0000     0.0011    -0.0005   -0.0005     0.0297      0.1365
# 3   XRPEUR      0.6784    -0.0018    -0.0010   -0.0010    -0.0826     -0.0593
# 4   XRPUSD      0.7707    -0.0004    -0.0011   -0.0011    -0.0818     -0.0524
# 5   LTCEUR    116.5900     0.0016    -0.0024   -0.0024    -0.1065     -0.1819
# 6   LTCBTC      0.0032     0.0000    -0.0026   -0.0026     0.0008     -0.0090
# 7   BCHEUR    341.0500    -0.0001    -0.0034   -0.0034    -0.1290     -0.1786
# 8   BCHBTC      0.0092     0.0000    -0.0037   -0.0037    -0.0234     -0.0056
# 9   ETHBTC      0.0766     0.0005    -0.0039   -0.0039    -0.0364     -0.1094
# 10  LTCUSD    132.2800    -0.0007    -0.0042   -0.0042    -0.1071     -0.1783
# 11  ETHEUR   2822.5700    -0.0008    -0.0045   -0.0045    -0.1392     -0.2624
# 12  ETHUSD   3204.9200    -0.0010    -0.0047   -0.0047    -0.1402     -0.2588
# 13  BCHUSD    387.2700    -0.0015    -0.0052   -0.0052    -0.1290     -0.1746
#
#     Perf Quart  Perf Half  Perf Year  Perf YTD
# 0      -0.2070     0.3057     0.1695   -0.1022
# 1      -0.2214     0.2577     0.0822   -0.1025
# 2      -0.0679    -0.0397     1.2829    0.0251
# 3      -0.2633     0.2527     1.6643   -0.0768
# 4      -0.2755     0.2089     1.4720   -0.0773
# 5      -0.2356     0.0170    -0.1156   -0.0964
# 6      -0.0332    -0.2201    -0.2422    0.0039
# 7      -0.3387    -0.1994    -0.0197   -0.1065
# 8      -0.1647    -0.3848    -0.1598   -0.0007
# 9       0.1535     0.1317     1.5308   -0.0358
# 10     -0.2494    -0.0214    -0.1826   -0.0987
# 11     -0.0871     0.4739     1.9578   -0.1348
# 12     -0.1035     0.4213     1.7372   -0.1357
# 13     -0.3498    -0.2284    -0.0932   -0.1051

# %% [markdown]
# # Group

# %%
from finvizfinance.group.overview import Overview
fgoverview = Overview()
df = fgoverview.screener_view(group='Industry')
df.tail()
# Out:
#                                Name Stocks    Market Cap Dividend    P/E  \
# 139  Utilities - Regulated Electric     37  7.939900e+11   0.0316  25.78
# 140       Utilities - Regulated Gas     15  8.172000e+10   0.0286  18.07
# 141     Utilities - Regulated Water     18  6.706000e+10   0.0148  32.26
# 142           Utilities - Renewable     18  7.024000e+10   0.0309  42.89
# 143                Waste Management     20  1.775200e+11   0.0099  45.87
#
#      Fwd P/E   PEG  Float Short  Change      Volume
# 139     1.66  3.84       0.0144  0.0074  67560000.0
# 140    18.19  3.88       0.0430 -0.0009  14400000.0
# 141    38.18   4.0       0.0189 -0.0101   6630000.0
# 142    46.88  1.81       0.0211  0.0011   8740000.0
# 143    32.36   3.5       0.0231 -0.0070   8920000.0

# %%
from finvizfinance.group.valuation import Valuation
fgvaluation = Valuation()
df = fgvaluation.screener_view(group='Industry')
df.tail()
# Out:
#                                Name Market Cap    P/E  Fwd P/E   PEG   P/S  \
# 139  Utilities - Regulated Electric    793.99B  25.78     1.66  3.84  1.95
# 140       Utilities - Regulated Gas     81.72B  18.07    18.19  3.88  2.13
# 141     Utilities - Regulated Water     67.06B  32.26    38.18   4.0  4.85
# 142           Utilities - Renewable     70.24B  42.89    46.88  1.81  4.21
# 143                Waste Management    177.52B  45.87    32.36   3.5  3.62
#
#       P/B    P/C   P/FCF  EPS past 5Y  EPS next 5Y Sales past 5Y  Change  \
# 139  1.19  36.51   65.73      -0.0073       0.0671        0.0194  0.0074
# 140  2.07  29.90   43.83       0.0526       0.0466        0.0305 -0.0009
# 141  3.08  42.19   60.68       0.0513       0.0807        0.0589 -0.0101
# 142  2.43  18.39  115.28      -0.1987       0.2371         0.093  0.0011
# 143  4.97  63.06   40.87       0.0767       0.1309        0.0701 -0.0070
#
#          Volume
# 139  67560000.0
# 140  14400000.0
# 141   6630000.0
# 142   8740000.0
# 143   8920000.0

# %%
from finvizfinance.group.performance import Performance
fgperformance = Performance()
df = fgperformance.screener_view(group='Industry')
df.tail()
# Out:
#                                Name Perf Week  Perf Month  Perf Quart  \
# 139  Utilities - Regulated Electric    -2.08%      0.0096      0.0678
# 140       Utilities - Regulated Gas    -0.77%      0.0326      0.0655
# 141     Utilities - Regulated Water    -6.68%     -0.0132      0.0324
# 142           Utilities - Renewable    -6.42%     -0.0518     -0.0469
# 143                Waste Management    -4.08%     -0.0269      0.0153
#
#      Perf Half  Perf Year  Perf YTD  Recom  Avg Volume  Rel Volume  Change  \
# 139     0.0634     0.0786   -0.0208   2.39  61520000.0        1.10  0.0074
# 140    -0.0039     0.0857   -0.0077   2.12  13350000.0        1.08 -0.0009
# 141     0.0753     0.0965   -0.0668   2.47   6090000.0        1.09 -0.0101
# 142    -0.0595    -0.2789   -0.0642   2.09   9380000.0        0.93  0.0011
# 143     0.1094     0.2828   -0.0408   2.14  11620000.0        0.77 -0.0070
#
#          Volume
# 139  67560000.0
# 140  14400000.0
# 141   6630000.0
# 142   8740000.0
# 143   8920000.0

# %% [markdown]
# # Earnings

# %%
from finvizfinance.earnings import Earnings

fEarnings = Earnings()
df_days = fEarnings.partition_days(mode='financial')

# %%
df_days['Jan 06/b']
# Out:
#    Ticker    Market Cap Dividend    ROA    ROE    ROI Curr R Quick R  \
# 0    ANGO  9.259500e+08     None  -0.06 -0.077 -0.067    2.5     1.6
# 1    BBBY  1.430000e+09     None  -0.03 -0.161 -0.047    1.4     0.7
# 2     CAG  1.654000e+10    0.036  0.054  0.143  0.093    1.0     0.3
# 3    HELE  5.560000e+09     None  0.092  0.174  0.162    1.8     0.8
# 4     LNN  1.490000e+09   0.0097  0.069  0.131  0.103    3.0     2.0
# 5      LW  1.020000e+10   0.0134  0.062  0.584  0.119    2.7     1.9
# 6    NTIC  1.328600e+08   0.0169  0.087  0.104   0.11    4.0     2.7
# 7     PKE  2.777000e+08   0.0296  0.041  0.049  0.025   18.7    18.0
# 8    SCHN  1.360000e+09   0.0154  0.117  0.217  0.193    1.5     0.8
# 9     STZ  4.588000e+10   0.0123  0.029   0.06  0.094    1.3     0.7
# 10    WBA  4.645000e+10   0.0347  0.029  0.117  0.046    0.7     0.3
#
#    LTDebt/Eq Debt/Eq Gross M Oper M Profit M  Earnings   Price  Change  \
# 0       0.06    0.06   0.541 -0.128   -0.115  Jan 06/b   23.43 -0.0421
# 1       1.26     0.0   0.347 -0.033   -0.021  Jan 06/b   13.80 -0.0437
# 2       1.03    1.08   0.276  0.151    0.108  Jan 06/b   34.75  0.0364
# 3       0.37    0.37   0.439  0.119    0.099  Jan 06/b  232.01 -0.0152
# 4       0.34    0.34   0.265  0.095    0.075  Jan 06/b  136.75 -0.0149
# 5       6.31    6.39   0.203  0.106    0.068  Jan 06/b   70.24  0.0357
# 6        0.0     0.0   0.346  0.147    0.111  Jan 06/b   15.36 -0.0007
# 7        0.0     0.0   0.322  0.171    0.129  Jan 06/b   13.52  0.0227
# 8       0.09    0.09   0.164  0.077     0.06  Jan 06/b   48.76  0.0577
# 9        0.9    0.94   0.525  0.241    0.086  Jan 06/b  246.18  0.0057
# 10      0.37    0.43   0.212  0.017    0.019  Jan 06/b   53.84  0.0267
#
#         Volume
# 0     886035.0
# 1   10211699.0
# 2    6121000.0
# 3     177685.0
# 4      73704.0
# 5    3026129.0
# 6       2035.0
# 7      77695.0
# 8     534312.0
# 9    1250353.0
# 10   7418273.0
